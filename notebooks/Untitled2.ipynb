# %% [markdown]
# # Keras to Core ML
#
# Needs downgrade to Keras 2.1.3

# %%
import coremltools
# Out:
# WARNING:root:TensorFlow version 1.10.1 detected. Last version known to be fully compatible is 1.5.0 .

# %%
coreml_model = coremltools.converters.keras.convert('epochs_200_datav2_densev2_try1_2018-09-13_23-16-16_weights.chkpt.hdf5', image_input_names='input1', output_names=['stenosis', 'anatomy'])
# Out:
# 0 : main_input, <keras.engine.topology.InputLayer object at 0x10c2fcc50>
# 1 : zero_padding2d_1, <keras.layers.convolutional.ZeroPadding2D object at 0x10c2fccc0>
# 2 : conv1/conv, <keras.layers.convolutional.Conv2D object at 0x10c2fcef0>
# 3 : conv1/bn, <keras.layers.normalization.BatchNormalization object at 0x10c3100b8>
# 4 : conv1/relu, <keras.layers.core.Activation object at 0x10c310358>
# 5 : zero_padding2d_2, <keras.layers.convolutional.ZeroPadding2D object at 0x10c310390>
# 6 : pool1, <keras.layers.pooling.MaxPooling2D object at 0x10c310400>
# 7 : conv2_block1_0_bn, <keras.layers.normalization.BatchNormalization object at 0x10c3104a8>
# 8 : conv2_block1_0_relu, <keras.layers.core.Activation object at 0x10c3105c0>
# 9 : conv2_block1_1_conv, <keras.layers.convolutional.Conv2D object at 0x10c3105f8>
# 10 : conv2_block1_1_bn, <keras.layers.normalization.BatchNormalization object at 0x10c310748>
# 11 : conv2_block1_1_relu, <keras.layers.core.Activation object at 0x10c310898>
# ...

# %%
coreml_model.save('CathNetv2_coreml.mlmodel')
